# %%
# !pip install google-play-scraper pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Tenx program/week-2
# Out:
# /content/drive/MyDrive/Tenx program/week-2

# %%
from scripts.review_scraper import scrape_reviews
from scripts.review_preprocessor import preprocess_reviews
import pandas as pd

# %%
banks = {
    'CBE': 'com.combanketh.mobilebanking',
    'BOA': 'com.boa.boaMobileBanking',
    'Dashen': 'com.dashen.dashensuperapp',
}

# %%
df_review = scrape_reviews(banks)
# Out:
# Scraping 400 reviews for CBE...
# Scraping 400 reviews for BOA...
# Scraping 400 reviews for Dashen...

# %%
df_review.tail()
# Out:
#                                                  review  rating        date  \
# 1195  It has a Good performance but need more upgrad...       4  2025-01-17
# 1196  It is a very wonderful work that has saved its...       5  2025-01-17
# 1197  “Life-changing!” I can’t imagine going back to...       5  2025-01-17
# 1198                                            Pro max       5  2025-01-17
# 1199                         The most good app and easy       5  2025-01-16
#
#         bank       source
# 1195  Dashen  Google Play
# 1196  Dashen  Google Play
# 1197  Dashen  Google Play
# 1198  Dashen  Google Play
# 1199  Dashen  Google Play

# %%
df_review.to_csv('./data/reviews_raw.csv', index=False)

# %%
df = pd.read_csv('./data/reviews_raw.csv')

# %%
df.head()
# Out:
#                                               review  rating        date bank  \
# 0  "Why don’t your ATMs support account-to-accoun...       4  2025-06-06  CBE
# 1                        what is this app problem???       1  2025-06-05  CBE
# 2       the app is proactive and a good connections.       5  2025-06-05  CBE
# 3    I cannot send to cbebirr app. through this app.       3  2025-06-05  CBE
# 4                                               good       4  2025-06-05  CBE
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play

# %%
df_preprocessed = preprocess_reviews(df)

# %%
df_preprocessed.head()
# Out:
#                                               review  rating        date bank  \
# 0  "Why don’t your ATMs support account-to-accoun...       4  2025-06-06  CBE
# 1                        what is this app problem???       1  2025-06-05  CBE
# 2       the app is proactive and a good connections.       5  2025-06-05  CBE
# 3    I cannot send to cbebirr app. through this app.       3  2025-06-05  CBE
# 4                                               good       4  2025-06-05  CBE
#
#         source
# 0  Google Play
# 1  Google Play
# 2  Google Play
# 3  Google Play
# 4  Google Play

# %%
df_preprocessed.to_csv('./data/reviews_preprocessed.csv', index=False)
